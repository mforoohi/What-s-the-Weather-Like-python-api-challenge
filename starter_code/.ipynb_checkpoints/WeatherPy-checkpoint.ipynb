# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
# Import API key
from api_keys import weather_api_key

from datetime import datetime

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities_maryam.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
units = "imperial"
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}&appid={weather_api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?&appid=021e21b97e69e74486caba6a7841762b&units=imperial&q='

# %%
#counter for records and set
counter = 0
sets = 1

#list to store api data
cities_in_api = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []


# loops for creating dataframe columns
print(" Beginning Data Retrieval ")
print("----------------------------------")
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
       # if counter > 50:
       #     counter = 1
         #   sets += 1
        cities_in_api.append(city)
       ### else:
            ##counter += 1
            #cities_in_api.append(city)
            
        print(f"Processing Record {counter} of Set {sets} | {city}")
    except Exception:
        print("City not found in the Database!!!!")
        
print("------------------------------")
print("Data Retrieval Complete")
# Out:
#  Beginning Data Retrieval
# ----------------------------------
# Processing Record 0 of Set 1 | mataura
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | mahebourg
# Processing Record 0 of Set 1 | deputatskiy
# Processing Record 0 of Set 1 | busselton
# Processing Record 0 of Set 1 | dandong
# Processing Record 0 of Set 1 | northam
# Processing Record 0 of Set 1 | thompson
# Processing Record 0 of Set 1 | sibolga
# Processing Record 0 of Set 1 | hilo
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | seoul
# Processing Record 0 of Set 1 | atuona
# Processing Record 0 of Set 1 | avarua
# Processing Record 0 of Set 1 | butaritari
# Processing Record 0 of Set 1 | gizo
# Processing Record 0 of Set 1 | ribeira grande
# Processing Record 0 of Set 1 | bagdarin
# Processing Record 0 of Set 1 | flinders
# Processing Record 0 of Set 1 | manokwari
# Processing Record 0 of Set 1 | norman wells
# Processing Record 0 of Set 1 | port elizabeth
# Processing Record 0 of Set 1 | mount gambier
# Processing Record 0 of Set 1 | sao gabriel da cachoeira
# Processing Record 0 of Set 1 | ushuaia
# Processing Record 0 of Set 1 | pisco
# Processing Record 0 of Set 1 | nanortalik
# Processing Record 0 of Set 1 | hermanus
# Processing Record 0 of Set 1 | codrington
# Processing Record 0 of Set 1 | kapaa
# Processing Record 0 of Set 1 | yellowknife
# Processing Record 0 of Set 1 | whitefish
# Processing Record 0 of Set 1 | gitega
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | yatou
# Processing Record 0 of Set 1 | westport
# Processing Record 0 of Set 1 | rikitea
# Processing Record 0 of Set 1 | albany
# Processing Record 0 of Set 1 | rajula
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | jamestown
# Processing Record 0 of Set 1 | lokosovo
# Processing Record 0 of Set 1 | buraydah
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | barrow
# Processing Record 0 of Set 1 | torbay
# Processing Record 0 of Set 1 | kodiak
# Processing Record 0 of Set 1 | tobane
# Processing Record 0 of Set 1 | punta arenas
# Processing Record 0 of Set 1 | cabo san lucas
# Processing Record 0 of Set 1 | olutanga
# Processing Record 0 of Set 1 | cidreira
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | ketchikan
# Processing Record 0 of Set 1 | port blair
# Processing Record 0 of Set 1 | mount isa
# Processing Record 0 of Set 1 | husavik
# Processing Record 0 of Set 1 | banswada
# Processing Record 0 of Set 1 | vaini
# Processing Record 0 of Set 1 | havoysund
# Processing Record 0 of Set 1 | eirunepe
# Processing Record 0 of Set 1 | dire
# Processing Record 0 of Set 1 | asyut
# Processing Record 0 of Set 1 | castro
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | balapur
# Processing Record 0 of Set 1 | east london
# Processing Record 0 of Set 1 | alugan
# Processing Record 0 of Set 1 | bethel
# Processing Record 0 of Set 1 | provideniya
# Processing Record 0 of Set 1 | silver city
# Processing Record 0 of Set 1 | cortez
# Processing Record 0 of Set 1 | nome
# Processing Record 0 of Set 1 | miles city
# Processing Record 0 of Set 1 | bredasdorp
# Processing Record 0 of Set 1 | benjamin constant
# Processing Record 0 of Set 1 | doume
# Processing Record 0 of Set 1 | iralaya
# Processing Record 0 of Set 1 | vilhena
# Processing Record 0 of Set 1 | pochutla
# Processing Record 0 of Set 1 | mar del plata
# Processing Record 0 of Set 1 | katsuura
# Processing Record 0 of Set 1 | bluff
# Processing Record 0 of Set 1 | marzuq
# Processing Record 0 of Set 1 | khatanga
# Processing Record 0 of Set 1 | cape town
# Processing Record 0 of Set 1 | faanui
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | kilindoni
# Processing Record 0 of Set 1 | barguzin
# Processing Record 0 of Set 1 | locri
# Processing Record 0 of Set 1 | waipawa
# Processing Record 0 of Set 1 | touros
# Processing Record 0 of Set 1 | dikson
# Processing Record 0 of Set 1 | puerto ayora
# Processing Record 0 of Set 1 | san patricio
# Processing Record 0 of Set 1 | ginda
# Processing Record 0 of Set 1 | guerrero negro
# Processing Record 0 of Set 1 | sao filipe
# Processing Record 0 of Set 1 | dingle
# Processing Record 0 of Set 1 | narsaq
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | bonavista
# Processing Record 0 of Set 1 | victoria
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | kabalo
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | esperance
# Processing Record 0 of Set 1 | luderitz
# Processing Record 0 of Set 1 | celestun
# Processing Record 0 of Set 1 | oron
# Processing Record 0 of Set 1 | nelson bay
# Processing Record 0 of Set 1 | san luis
# Processing Record 0 of Set 1 | onega
# Processing Record 0 of Set 1 | peterhead
# Processing Record 0 of Set 1 | saint george
# Processing Record 0 of Set 1 | hobart
# Processing Record 0 of Set 1 | margate
# Processing Record 0 of Set 1 | segovia
# Processing Record 0 of Set 1 | new norfolk
# Processing Record 0 of Set 1 | vardo
# Processing Record 0 of Set 1 | puerto madryn
# Processing Record 0 of Set 1 | avrille
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | tokur
# Processing Record 0 of Set 1 | bahar
# Processing Record 0 of Set 1 | lorengau
# Processing Record 0 of Set 1 | balakhninskiy
# Processing Record 0 of Set 1 | madison
# Processing Record 0 of Set 1 | saldanha
# Processing Record 0 of Set 1 | praia da vitoria
# Processing Record 0 of Set 1 | vanimo
# Processing Record 0 of Set 1 | wum
# Processing Record 0 of Set 1 | tabou
# Processing Record 0 of Set 1 | srednekolymsk
# Processing Record 0 of Set 1 | vengerovo
# Processing Record 0 of Set 1 | port alfred
# Processing Record 0 of Set 1 | ponta delgada
# Processing Record 0 of Set 1 | saint-philippe
# Processing Record 0 of Set 1 | lagoa
# Processing Record 0 of Set 1 | road town
# Processing Record 0 of Set 1 | jumla
# Processing Record 0 of Set 1 | paamiut
# Processing Record 0 of Set 1 | bodden town
# Processing Record 0 of Set 1 | progreso
# Processing Record 0 of Set 1 | krasnoselkup
# Processing Record 0 of Set 1 | beringovskiy
# Processing Record 0 of Set 1 | pacific grove
# Processing Record 0 of Set 1 | makubetsu
# Processing Record 0 of Set 1 | jiazi
# Processing Record 0 of Set 1 | charcas
# Processing Record 0 of Set 1 | umm lajj
# Processing Record 0 of Set 1 | padang
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | yablochnyy
# Processing Record 0 of Set 1 | omsukchan
# Processing Record 0 of Set 1 | qaanaaq
# Processing Record 0 of Set 1 | illela
# Processing Record 0 of Set 1 | biak
# Processing Record 0 of Set 1 | euclides da cunha
# Processing Record 0 of Set 1 | fortuna
# Processing Record 0 of Set 1 | iqaluit
# Processing Record 0 of Set 1 | lompoc
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | bambous virieux
# Processing Record 0 of Set 1 | sao joao da barra
# Processing Record 0 of Set 1 | ponta do sol
# Processing Record 0 of Set 1 | vilyuysk
# Processing Record 0 of Set 1 | tiksi
# Processing Record 0 of Set 1 | saskylakh
# Processing Record 0 of Set 1 | hasaki
# Processing Record 0 of Set 1 | okhotsk
# Processing Record 0 of Set 1 | hervey bay
# Processing Record 0 of Set 1 | gwadar
# Processing Record 0 of Set 1 | huarmey
# Processing Record 0 of Set 1 | the valley
# Processing Record 0 of Set 1 | bud
# Processing Record 0 of Set 1 | sechura
# Processing Record 0 of Set 1 | mujiayingzi
# Processing Record 0 of Set 1 | emba
# Processing Record 0 of Set 1 | deniliquin
# Processing Record 0 of Set 1 | caravelas
# Processing Record 0 of Set 1 | kongsberg
# Processing Record 0 of Set 1 | ust-ilimsk
# Processing Record 0 of Set 1 | dunedin
# Processing Record 0 of Set 1 | cherskiy
# Processing Record 0 of Set 1 | muros
# Processing Record 0 of Set 1 | richards bay
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | arraial do cabo
# Processing Record 0 of Set 1 | komsomolskiy
# Processing Record 0 of Set 1 | santa luzia
# Processing Record 0 of Set 1 | calvinia
# Processing Record 0 of Set 1 | fort frances
# Processing Record 0 of Set 1 | tuktoyaktuk
# Processing Record 0 of Set 1 | san quintin
# Processing Record 0 of Set 1 | sydney
# Processing Record 0 of Set 1 | tasiilaq
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | krasnogorskiy
# Processing Record 0 of Set 1 | ostrovnoy
# Processing Record 0 of Set 1 | huanren
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | ilulissat
# Processing Record 0 of Set 1 | severo-kurilsk
# Processing Record 0 of Set 1 | antalaha
# Processing Record 0 of Set 1 | marsh harbour
# Processing Record 0 of Set 1 | lebu
# Processing Record 0 of Set 1 | chokurdakh
# Processing Record 0 of Set 1 | santa maria
# Processing Record 0 of Set 1 | hambantota
# Processing Record 0 of Set 1 | tura
# Processing Record 0 of Set 1 | whitehorse
# Processing Record 0 of Set 1 | college
# Processing Record 0 of Set 1 | coihaique
# Processing Record 0 of Set 1 | russell
# Processing Record 0 of Set 1 | oistins
# Processing Record 0 of Set 1 | puerto escondido
# Processing Record 0 of Set 1 | ous
# Processing Record 0 of Set 1 | santa branca
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | serafimovich
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | yerbogachen
# Processing Record 0 of Set 1 | ipora
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | sinnamary
# Processing Record 0 of Set 1 | manono
# Processing Record 0 of Set 1 | longwy
# Processing Record 0 of Set 1 | kavieng
# Processing Record 0 of Set 1 | inta
# Processing Record 0 of Set 1 | gushikawa
# Processing Record 0 of Set 1 | upernavik
# Processing Record 0 of Set 1 | belaya gora
# Processing Record 0 of Set 1 | kailua
# Processing Record 0 of Set 1 | lavrentiya
# Processing Record 0 of Set 1 | upata
# Processing Record 0 of Set 1 | bjelovar
# Processing Record 0 of Set 1 | barcelos
# Processing Record 0 of Set 1 | erenhot
# Processing Record 0 of Set 1 | hithadhoo
# Processing Record 0 of Set 1 | garden city
# Processing Record 0 of Set 1 | xining
# Processing Record 0 of Set 1 | trairi
# Processing Record 0 of Set 1 | nynashamn
# Processing Record 0 of Set 1 | winnemucca
# Processing Record 0 of Set 1 | marihatag
# Processing Record 0 of Set 1 | zarubino
# Processing Record 0 of Set 1 | leningradskiy
# Processing Record 0 of Set 1 | yate
# Processing Record 0 of Set 1 | kogon
# Processing Record 0 of Set 1 | georgetown
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | balkanabat
# Processing Record 0 of Set 1 | aracati
# Processing Record 0 of Set 1 | brae
# Processing Record 0 of Set 1 | boa vista
# Processing Record 0 of Set 1 | aden
# Processing Record 0 of Set 1 | ravar
# Processing Record 0 of Set 1 | pekalongan
# Processing Record 0 of Set 1 | mayo
# Processing Record 0 of Set 1 | turukhansk
# Processing Record 0 of Set 1 | chambersburg
# Processing Record 0 of Set 1 | carnarvon
# Processing Record 0 of Set 1 | walla walla
# Processing Record 0 of Set 1 | maumere
# Processing Record 0 of Set 1 | klyuchi
# Processing Record 0 of Set 1 | san juan
# Processing Record 0 of Set 1 | lalsot
# Processing Record 0 of Set 1 | abu samrah
# Processing Record 0 of Set 1 | lieksa
# Processing Record 0 of Set 1 | alyangula
# Processing Record 0 of Set 1 | carroll
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | meulaboh
# Processing Record 0 of Set 1 | sokolo
# Processing Record 0 of Set 1 | horsham
# Processing Record 0 of Set 1 | wamba
# Processing Record 0 of Set 1 | alliston
# Processing Record 0 of Set 1 | grindavik
# Processing Record 0 of Set 1 | longyearbyen
# Processing Record 0 of Set 1 | vilcun
# Processing Record 0 of Set 1 | yelizovo
# Processing Record 0 of Set 1 | talas
# Processing Record 0 of Set 1 | alofi
# Processing Record 0 of Set 1 | inhambane
# Processing Record 0 of Set 1 | colonia
# Processing Record 0 of Set 1 | gazanjyk
# Processing Record 0 of Set 1 | tiznit
# Processing Record 0 of Set 1 | jizan
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | sorong
# Processing Record 0 of Set 1 | shingu
# Processing Record 0 of Set 1 | port hedland
# Processing Record 0 of Set 1 | isangel
# Processing Record 0 of Set 1 | ransang
# Processing Record 0 of Set 1 | delfzijl
# Processing Record 0 of Set 1 | bundaberg
# Processing Record 0 of Set 1 | baoying
# Processing Record 0 of Set 1 | vestmannaeyjar
# Processing Record 0 of Set 1 | moussoro
# Processing Record 0 of Set 1 | sortland
# Processing Record 0 of Set 1 | ancud
# Processing Record 0 of Set 1 | cururupu
# Processing Record 0 of Set 1 | pevek
# Processing Record 0 of Set 1 | qingdao
# Processing Record 0 of Set 1 | alvaraes
# Processing Record 0 of Set 1 | kudahuvadhoo
# Processing Record 0 of Set 1 | san ignacio
# Processing Record 0 of Set 1 | aswan
# Processing Record 0 of Set 1 | zapolyarnyy
# Processing Record 0 of Set 1 | kyra
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | boguchany
# Processing Record 0 of Set 1 | kieta
# Processing Record 0 of Set 1 | chuy
# Processing Record 0 of Set 1 | kaitangata
# City not found in the Database!!!!
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | zheleznodorozhnyy
# Processing Record 0 of Set 1 | kruisfontein
# Processing Record 0 of Set 1 | port keats
# Processing Record 0 of Set 1 | bulawayo
# Processing Record 0 of Set 1 | pemangkat
# Processing Record 0 of Set 1 | linqiong
# Processing Record 0 of Set 1 | grand gaube
# Processing Record 0 of Set 1 | mukhen
# Processing Record 0 of Set 1 | tilichiki
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | matao
# Processing Record 0 of Set 1 | tombouctou
# Processing Record 0 of Set 1 | ahipara
# Processing Record 0 of Set 1 | segou
# Processing Record 0 of Set 1 | tanete
# Processing Record 0 of Set 1 | nola
# Processing Record 0 of Set 1 | suoyarvi
# Processing Record 0 of Set 1 | si sa ket
# Processing Record 0 of Set 1 | kuching
# Processing Record 0 of Set 1 | la asuncion
# Processing Record 0 of Set 1 | nishihara
# Processing Record 0 of Set 1 | port shepstone
# Processing Record 0 of Set 1 | imeni poliny osipenko
# Processing Record 0 of Set 1 | gat
# Processing Record 0 of Set 1 | talnakh
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | save
# Processing Record 0 of Set 1 | liverpool
# Processing Record 0 of Set 1 | akhmeta
# Processing Record 0 of Set 1 | kaura namoda
# Processing Record 0 of Set 1 | alzey
# Processing Record 0 of Set 1 | cayenne
# Processing Record 0 of Set 1 | souillac
# Processing Record 0 of Set 1 | shenjiamen
# Processing Record 0 of Set 1 | rio gallegos
# Processing Record 0 of Set 1 | ulladulla
# Processing Record 0 of Set 1 | coquimbo
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | aviles
# Processing Record 0 of Set 1 | kahului
# Processing Record 0 of Set 1 | te anau
# Processing Record 0 of Set 1 | clyde river
# Processing Record 0 of Set 1 | bengkulu
# Processing Record 0 of Set 1 | port-gentil
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | sumbawanga
# Processing Record 0 of Set 1 | acapulco
# Processing Record 0 of Set 1 | coahuayana
# Processing Record 0 of Set 1 | makakilo city
# Processing Record 0 of Set 1 | chuka
# Processing Record 0 of Set 1 | harlingen
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | maniitsoq
# Processing Record 0 of Set 1 | tuatapere
# Processing Record 0 of Set 1 | kidal
# Processing Record 0 of Set 1 | nurlat
# Processing Record 0 of Set 1 | quanzhou
# Processing Record 0 of Set 1 | tagusao
# Processing Record 0 of Set 1 | berlevag
# Processing Record 0 of Set 1 | auki
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | camana
# Processing Record 0 of Set 1 | klaksvik
# Processing Record 0 of Set 1 | svetlogorsk
# Processing Record 0 of Set 1 | san jose
# Processing Record 0 of Set 1 | dudinka
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | fort nelson
# Processing Record 0 of Set 1 | roald
# Processing Record 0 of Set 1 | samarai
# Processing Record 0 of Set 1 | paka
# Processing Record 0 of Set 1 | adrar
# Processing Record 0 of Set 1 | rio grande
# Processing Record 0 of Set 1 | patea
# Processing Record 0 of Set 1 | airai
# Processing Record 0 of Set 1 | anadyr
# Processing Record 0 of Set 1 | nyimba
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | itarema
# Processing Record 0 of Set 1 | olafsvik
# Processing Record 0 of Set 1 | chernyshevskiy
# Processing Record 0 of Set 1 | atambua
# Processing Record 0 of Set 1 | morden
# Processing Record 0 of Set 1 | antofagasta
# Processing Record 0 of Set 1 | kortkeros
# Processing Record 0 of Set 1 | namibe
# City not found in the Database!!!!
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | ordu
# Processing Record 0 of Set 1 | saint-pierre
# Processing Record 0 of Set 1 | jinchang
# Processing Record 0 of Set 1 | awbari
# Processing Record 0 of Set 1 | korla
# Processing Record 0 of Set 1 | atar
# Processing Record 0 of Set 1 | concepcion del uruguay
# Processing Record 0 of Set 1 | poum
# Processing Record 0 of Set 1 | cabedelo
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | tuim
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | constitucion
# Processing Record 0 of Set 1 | kattivakkam
# Processing Record 0 of Set 1 | kalabo
# Processing Record 0 of Set 1 | nyurba
# Processing Record 0 of Set 1 | thanatpin
# Processing Record 0 of Set 1 | san vicente
# Processing Record 0 of Set 1 | vanavara
# Processing Record 0 of Set 1 | misratah
# Processing Record 0 of Set 1 | naze
# Processing Record 0 of Set 1 | shelburne
# Processing Record 0 of Set 1 | kaolinovo
# Processing Record 0 of Set 1 | emerald
# Processing Record 0 of Set 1 | salalah
# Processing Record 0 of Set 1 | safaga
# Processing Record 0 of Set 1 | nalut
# Processing Record 0 of Set 1 | tucuman
# Processing Record 0 of Set 1 | vostok
# Processing Record 0 of Set 1 | soderhamn
# Processing Record 0 of Set 1 | raudeberg
# Processing Record 0 of Set 1 | olbia
# Processing Record 0 of Set 1 | pokhara
# Processing Record 0 of Set 1 | saint-augustin
# Processing Record 0 of Set 1 | opuwo
# Processing Record 0 of Set 1 | cap malheureux
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | teya
# Processing Record 0 of Set 1 | tilaran
# Processing Record 0 of Set 1 | isla vista
# Processing Record 0 of Set 1 | matipo
# Processing Record 0 of Set 1 | egvekinot
# Processing Record 0 of Set 1 | taunggyi
# Processing Record 0 of Set 1 | luanda
# Processing Record 0 of Set 1 | isiolo
# Processing Record 0 of Set 1 | hobara
# Processing Record 0 of Set 1 | shumerlya
# Processing Record 0 of Set 1 | estrela
# Processing Record 0 of Set 1 | garowe
# Processing Record 0 of Set 1 | batemans bay
# Processing Record 0 of Set 1 | sidhauli
# Processing Record 0 of Set 1 | bievre
# Processing Record 0 of Set 1 | roma
# Processing Record 0 of Set 1 | voyvozh
# Processing Record 0 of Set 1 | portoferraio
# Processing Record 0 of Set 1 | katangli
# Processing Record 0 of Set 1 | bombay
# Processing Record 0 of Set 1 | kallaste
# Processing Record 0 of Set 1 | vitim
# Processing Record 0 of Set 1 | mancio lima
# Processing Record 0 of Set 1 | evensk
# Processing Record 0 of Set 1 | borzya
# Processing Record 0 of Set 1 | elizabeth city
# Processing Record 0 of Set 1 | sawakin
# Processing Record 0 of Set 1 | skjervoy
# Processing Record 0 of Set 1 | necochea
# Processing Record 0 of Set 1 | orange cove
# Processing Record 0 of Set 1 | nong chik
# Processing Record 0 of Set 1 | babu
# Processing Record 0 of Set 1 | saurimo
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | faro
# Processing Record 0 of Set 1 | ammon
# Processing Record 0 of Set 1 | ixtapa
# Processing Record 0 of Set 1 | krasnovishersk
# Processing Record 0 of Set 1 | pokosnoye
# Processing Record 0 of Set 1 | coruripe
# Processing Record 0 of Set 1 | bandarbeyla
# Processing Record 0 of Set 1 | mehamn
# Processing Record 0 of Set 1 | bonoua
# Processing Record 0 of Set 1 | pangnirtung
# Processing Record 0 of Set 1 | hofn
# Processing Record 0 of Set 1 | tautira
# Processing Record 0 of Set 1 | barcelona
# Processing Record 0 of Set 1 | burns lake
# Processing Record 0 of Set 1 | mandera
# Processing Record 0 of Set 1 | torbat-e jam
# Processing Record 0 of Set 1 | somerset east
# Processing Record 0 of Set 1 | wencheng
# Processing Record 0 of Set 1 | matamoros
# Processing Record 0 of Set 1 | lashio
# Processing Record 0 of Set 1 | peace river
# Processing Record 0 of Set 1 | piacabucu
# Processing Record 0 of Set 1 | pemba
# Processing Record 0 of Set 1 | yantal
# Processing Record 0 of Set 1 | corowa
# Processing Record 0 of Set 1 | wilmington
# Processing Record 0 of Set 1 | hermosillo
# Processing Record 0 of Set 1 | alta floresta
# Processing Record 0 of Set 1 | mitchell
# Processing Record 0 of Set 1 | talara
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | marsaxlokk
# Processing Record 0 of Set 1 | taltal
# Processing Record 0 of Set 1 | ust-omchug
# Processing Record 0 of Set 1 | malakal
# Processing Record 0 of Set 1 | ndende
# Processing Record 0 of Set 1 | hengyang
# Processing Record 0 of Set 1 | quatre cocos
# Processing Record 0 of Set 1 | kharan
# Processing Record 0 of Set 1 | bilma
# Processing Record 0 of Set 1 | santa quiteria
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | mayor pablo lagerenza
# Processing Record 0 of Set 1 | sitka
# Processing Record 0 of Set 1 | champerico
# Processing Record 0 of Set 1 | yenagoa
# Processing Record 0 of Set 1 | aranos
# Processing Record 0 of Set 1 | beyneu
# Processing Record 0 of Set 1 | hirara
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | cooma
# Processing Record 0 of Set 1 | huinan
# Processing Record 0 of Set 1 | najran
# Processing Record 0 of Set 1 | morelia
# Processing Record 0 of Set 1 | usinsk
# Processing Record 0 of Set 1 | nouadhibou
# Processing Record 0 of Set 1 | oranjemund
# Processing Record 0 of Set 1 | bac lieu
# Processing Record 0 of Set 1 | pusad
# Processing Record 0 of Set 1 | roebourne
# Processing Record 0 of Set 1 | falkenberg
# Processing Record 0 of Set 1 | manuk mangkaw
# Processing Record 0 of Set 1 | cafelandia
# Processing Record 0 of Set 1 | phon thong
# Processing Record 0 of Set 1 | gombong
# Processing Record 0 of Set 1 | cabinda
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | kayes
# Processing Record 0 of Set 1 | haapiti
# Processing Record 0 of Set 1 | chase
# Processing Record 0 of Set 1 | moose factory
# Processing Record 0 of Set 1 | huilong
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | lucapa
# Processing Record 0 of Set 1 | san ramon
# Processing Record 0 of Set 1 | cerro punta
# Processing Record 0 of Set 1 | hamilton
# Processing Record 0 of Set 1 | union hidalgo
# Processing Record 0 of Set 1 | rumuruti
# Processing Record 0 of Set 1 | phonhong
# Processing Record 0 of Set 1 | yambio
# Processing Record 0 of Set 1 | praya
# Processing Record 0 of Set 1 | uige
# Processing Record 0 of Set 1 | taoudenni
# Processing Record 0 of Set 1 | fare
# Processing Record 0 of Set 1 | myitkyina
# Processing Record 0 of Set 1 | cockburn town
# Processing Record 0 of Set 1 | kefamenanu
# Processing Record 0 of Set 1 | nikolskoye
# Processing Record 0 of Set 1 | kandrian
# Processing Record 0 of Set 1 | vorokhta
# Processing Record 0 of Set 1 | wawa
# Processing Record 0 of Set 1 | sao felix do xingu
# Processing Record 0 of Set 1 | lima
# City not found in the Database!!!!
# Processing Record 0 of Set 1 | chikwawa
# Processing Record 0 of Set 1 | miraflores
# Processing Record 0 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 0 of Set 1 | takoradi
# Processing Record 0 of Set 1 | neiafu
# Processing Record 0 of Set 1 | petatlan
# Processing Record 0 of Set 1 | ozernovskiy
# Processing Record 0 of Set 1 | henties bay
# Processing Record 0 of Set 1 | kutum
# Processing Record 0 of Set 1 | ayna
# Processing Record 0 of Set 1 | burnie
# Processing Record 0 of Set 1 | tarakan
# Processing Record 0 of Set 1 | idah
# Processing Record 0 of Set 1 | hongjiang
# Processing Record 0 of Set 1 | saravena
# Processing Record 0 of Set 1 | sanchor
# Processing Record 0 of Set 1 | saint-joseph
# Processing Record 0 of Set 1 | kuminskiy
# Processing Record 0 of Set 1 | ternuvate
# Processing Record 0 of Set 1 | saint-paul
# Processing Record 0 of Set 1 | marawi
# Processing Record 0 of Set 1 | half moon bay
# Processing Record 0 of Set 1 | bestobe
# Processing Record 0 of Set 1 | nandurbar
# ------------------------------
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict={
      "City": cities_in_api,
      "Lat":lats,
      "Lng":lngs,
      "Max Temp":max_temps,
      "Humidity":humidities,
      "Cloudiness":cloudinesses,
      "Wind Speed":wind_speeds,
      "Country":countries,
      "Date":dates
    }

# %%
weather_df=pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      mataura -46.1927  168.8643     38.48        92          94        4.05
# 1    mahebourg -20.4081   57.7000     70.09        78          20        5.75
# 2  deputatskiy  69.3000  139.9000     43.99        80          59        4.74
# 3    busselton -33.6500  115.3333     56.08        75          97       15.70
# 4      dandong  40.1292  124.3947     72.50        85          29        2.95
#
#   Country        Date
# 0      NZ  1627145383
# 1      MU  1627145336
# 2      RU  1627145212
# 3      AU  1627145182
# 4      CN  1627145454

# %%
weather_df.to_csv(output_data_file )

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  551.000000  551.000000  551.000000  551.000000  551.000000  551.000000
# mean    19.355871   19.545422   71.115572   68.343013   55.493648    8.211670
# std     33.297751   90.913875   15.255337   22.181244   38.348159    5.784633
# min    -54.800000 -179.166700   34.610000    5.000000    0.000000    0.000000
# 25%     -7.764050  -59.135050   59.515000   55.000000   16.000000    3.990000
# 50%     21.283300   22.681400   73.990000   72.000000   68.000000    6.910000
# 75%     48.193450  102.348150   81.755000   86.000000   94.000000   11.330000
# max     78.218600  179.316700  112.820000  100.000000  100.000000   48.990000
#
#                Date
# count  5.510000e+02
# mean   1.627145e+09
# std    1.289747e+02
# min    1.627145e+09
# 25%    1.627145e+09
# 50%    1.627145e+09
# 75%    1.627146e+09
# max    1.627146e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
Humidity_df =weather_df[(weather_df['Humidity'] > 100)]
H_index=Humidity_df.index

weather_df.drop(H_index)
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_data =weather_df[(weather_df['Humidity'] <= 100)]
                            #,on=index,inplace=False)
clean_city_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    nandurbar -46.1927  168.8643     56.48        67          14        4.12
# 1    nandurbar  62.0589   48.6201     46.11        90          99        6.58
# 2    nandurbar -20.4081   57.7000     68.25        75          50        9.95
# 3    nandurbar  69.3000  139.9000     61.95        50          89       10.33
# 4    nandurbar -33.6500  115.3333     57.04        71         100       14.00
# ..         ...      ...       ...       ...       ...         ...         ...
# 534  nandurbar -21.0096   55.2707     66.31        60           2        4.34
# 535  nandurbar   7.9986  124.2928     86.65        52          11        7.36
# 536  nandurbar   6.3807  -10.6953     74.98        87         100        8.05
# 537  nandurbar  52.4994   73.0975     76.86        32           0        5.84
# 538  nandurbar  21.3667   74.2500     78.51        87          58       15.68
#
#     Country        Date
# 0        NZ  1627092647
# 1        RU  1627092648
# 2        MU  1627092648
# 3        RU  1627092158
# 4        AU  1627092649
# ..      ...         ...
# 534      RE  1627092855
# 535      PH  1627092855
# 536      LR  1627092856
# 537      KZ  1627092856
# 538      IN  1627092856
#
# [539 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
endRunDate = weather_df["Date"].max()
runDate = datetime.utcfromtimestamp(endRunDate).strftime('%Y-%m-%d')

plt.scatter(weather_df["Lat"],weather_df["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title(f"City Latitude vs. Max Temperature {runDate}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../output_data/fig1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title(f"City Latitude vs. Humidity {runDate}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../output_data/fig2.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title(f"City Latitude vs. Cloudiness {runDate}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../output_data/fig3.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title(f"City Latitude vs. Wind Speed {runDate}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../output_data/fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f'The r-square is {rvalue}')
    print(line_eq)
    plt.annotate(line_eq,(regEQplotX,regEQplotY),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{y_label}')
    plt.grid()

# %%
Northern_df = weather_df.loc[weather_df["Lat"] > 0]
Southern_df = weather_df.loc[weather_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set the data sets to compare
x_values = Northern_df["Lat"]
y_values = Northern_df["Max Temp"]
#tweak where the equation appears on the plot
regEQplotX = 0
regEQplotY = 40
#label the y axis
y_label = "Temperature (F)"
#give the title
plt.title(f'Northern Hemisphere Latitude vs Temp on {runDate}')
#run the function with all 5 variables
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
#save as a png to the neighboring output_data folder
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Temp on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.6709958150348847
# y = -0.44x + 87.92

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern_df["Lat"]
y_values = Southern_df["Max Temp"]
regEQplotX = -25
regEQplotY = 40
y_label = "Temperature (F)"
plt.title(f'Southern Hemisphere Latitude vs Temp on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Temp on {runDate}.png')
plt.show()
# Out:
# The r-square is 0.720940791667783
# y = 0.69x + 78.47

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern_df["Lat"]
y_values = Northern_df["Humidity"]
regEQplotX = 45
regEQplotY = 15
y_label = "Humidity (%)"
#plt.title(f'Northern Hemisphere Latitude vs Humidity on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
#plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Humidity on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.03111436908279158
# y = -0.03x + 73.96

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern_df["Lat"]
y_values = Southern_df["Humidity"]
regEQplotX = -55
regEQplotY = 35
y_label = "Humidity (%)"
plt.title(f'Southern Hemisphere Latitude vs Humidity on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Humidity on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.004518884411974594
# y = -0.01x + 67.96

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern_df["Lat"]
y_values = Northern_df["Cloudiness"]
regEQplotX = 0
regEQplotY = 25
y_label = "Cloudiness (%)"
plt.title(f'Northern Hemisphere Latitude vs Cloudiness on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)

plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Cloudiness on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.016086605746414444
# y = -0.03x + 60.3

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern_df["Lat"]
y_values = Southern_df["Cloudiness"]
regEQplotX = -55
regEQplotY = 60
y_label = "Cloudiness (%)"
plt.title(f'Southern Hemisphere Latitude vs Cloudiness on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Cloudiness on {runDate}.png')
plt.show()
# Out:
# The r-square is 0.09923065296916124
# y = 0.29x + 46.41

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern_df["Lat"]
y_values = Northern_df["Wind Speed"]
regEQplotX = 35
regEQplotY = 25
y_label = "Wind Speed (MPH)"
plt.title(f'Northern Hemisphere Latitude vs Wind Speed on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Northern Hemisphere Latitude vs Wind Speed on {runDate}.png')
plt.show()
# Out:
# The r-square is 0.04125208744471535
# y = 0.01x + 7.64

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern_df["Lat"]
y_values = Southern_df["Wind Speed"]
regEQplotX = -50
regEQplotY = 25
y_label = "Wind Speed (MPH)"
plt.title(f'Southern Hemisphere Latitude vs Wind Speed on {runDate}')
linearRegression(x_values,y_values,regEQplotX,regEQplotY,y_label)
plt.savefig(f'../output_data/Southern Hemisphere Latitude vs Wind Speed on {runDate}.png')
plt.show()
# Out:
# The r-square is -0.09108095301833329
# y = -0.04x + 7.62
